# %%
import pandas as pd

# %%
#uber_df = pd.read_csv('Uber_CSV_071921.csv')

# %%
#uber_df.head()
# Out:
#        Driver Name  Phone Number                    Email  \
# 0  Michael Batista           NaN  mikebatista@hotmail.com
# 1  Michael Batista           NaN  mikebatista@hotmail.com
# 2  Michael Batista           NaN  mikebatista@hotmail.com
# 3  Michael Batista           NaN  mikebatista@hotmail.com
# 4  Michael Batista           NaN  mikebatista@hotmail.com
#
#                           Date/Time                               Trip ID  \
# 0     Sunday, July 18, 2021 1:15 AM  027df95c-8933-4c3e-b579-470b9e44bad2
# 1     Sunday, July 18, 2021 1:38 AM  7f5c7083-3604-4996-93ce-bca89f1a8399
# 2     Sunday, July 18, 2021 4:36 AM  eccd3c79-6aac-4ef9-ae43-bbcc7acd2b9c
# 3  Saturday, July 17, 2021 10:55 AM  addcf44b-9362-4c92-8934-ffe8e9f24182
# 4     Sunday, July 18, 2021 1:33 AM  d396c005-19b3-4b08-a192-a8a05c1c8347
#
#     Type Fare Base Fare Cancellation Fare Trip Supplement Fare Distance  \
# 0  UberX     $1.80               NaN                  NaN         $5.77
# ...

# %%
fangraphs_df = pd.read_csv('FG_Dataset.csv')

# %%
fangraphs_df.head()
# Out:
#                 Name Team   PA  Events    EV  maxEV    LA  Barrels Barrel%  \
# 0         Joey Gallo  TEX  577     293  94.2  117.5  21.9       64   21.8%
# 1        Nelson Cruz  SEA  591     400  93.9  117.0  13.0       54   13.5%
# 2  Giancarlo Stanton  NYY  705     416  93.8  121.7  11.6       61   14.7%
# 3         Matt Olson  OAK  660     419  93.3  113.3  18.1       48   11.5%
# 4       Matt Chapman  OAK  616     403  93.1  115.3  14.9       33    8.2%
#
#    HardHit HardHit%    AVG    xBA    SLG   xSLG   wOBA  xwOBA  playerid
# 0      142    48.5%  0.206  0.230  0.498  0.544  0.343  0.370     14128
# 1      203    50.8%  0.256  0.280  0.509  0.565  0.361  0.393      2434
# 2      210    50.5%  0.266  0.242  0.509  0.477  0.360  0.344      4949
# 3      218    52.0%  0.247  0.249  0.453  0.490  0.340  0.355     14344
# 4      192    47.6%  0.278  0.253  0.508  0.428  0.369  0.335     16505

# %%
fangraphs_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140 entries, 0 to 139
# Data columns (total 18 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      140 non-null    object
#  1   Team      140 non-null    object
#  2   PA        140 non-null    int64
#  3   Events    140 non-null    int64
#  4   EV        140 non-null    float64
#  5   maxEV     140 non-null    float64
#  6   LA        140 non-null    float64
#  7   Barrels   140 non-null    int64
#  8   Barrel%   140 non-null    object
#  9   HardHit   140 non-null    int64
#  10  HardHit%  140 non-null    object
#  11  AVG       140 non-null    float64
#  12  xBA       140 non-null    float64
#  13  SLG       140 non-null    float64
#  14  xSLG      140 non-null    float64
#  15  wOBA      140 non-null    float64
#  16  xwOBA     140 non-null    float64
#  17  playerid  140 non-null    int64
# dtypes: float64(9), int64(5), object(4)
# memory usage: 19.8+ KB

# %%
covid_df = pd.read_csv('owid-covid-data.csv')

# %%
covid_df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1      AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# ...

# %%
covid_df.transpose()
# Out:
#                                              0            1            2      \
# iso_code                                       AFG          AFG          AFG
# continent                                     Asia         Asia         Asia
# location                               Afghanistan  Afghanistan  Afghanistan
# date                                    2020-02-24   2020-02-25   2020-02-26
# total_cases                                      1            1            1
# new_cases                                        1            0            0
# new_cases_smoothed                             NaN          NaN          NaN
# total_deaths                                   NaN          NaN          NaN
# new_deaths                                     NaN          NaN          NaN
# new_deaths_smoothed                            NaN          NaN          NaN
# total_cases_per_million                      0.026        0.026        0.026
# ...
